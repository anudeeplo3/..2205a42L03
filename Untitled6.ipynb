# %% [markdown]
# <a href="https://colab.research.google.com/github/anudeeplo3/..2205a42L03/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
data  = pd.read_csv("/content/drive/MyDrive/used car price2.csv")
data.head()
# Out:
#                        Name year(below2018) year(above2019)  selling_price  \
# 0             Maruti 800 AC             yes              No          60000
# 1  Maruti Wagon R LXI Minor             yes              No         135000
# 2      Hyundai Verna 1.6 SX             yes              No         600000
# 3    Datsun RediGO T Option             yes              No         250000
# 4     Honda Amaze VX i-DTEC             yes              No         450000
#
#    Km_driven fuel_type seller_type transmission single_owner multiple_owner
# 0      70000    Petrol  Individual       Manual          yes             No
# 1      50000    Petrol  Individual       Manual          yes             No
# 2     100000    Diesel  Individual       Manual          yes             No
# 3      46000    Petrol  Individual       Manual          yes             No
# 4     141000    Diesel  Individual       Manual           No            yes

# %%
# Checking for null values
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0              Name  99 non-null     object
#  1   year(below2018)  99 non-null     object
#  2   year(above2019)  99 non-null     object
#  3   selling_price    99 non-null     int64
#  4   Km_driven        99 non-null     int64
#  5   fuel_type        99 non-null     object
#  6   seller_type      99 non-null     object
#  7   transmission     99 non-null     object
#  8   single_owner     99 non-null     object
#  9   multiple_owner   99 non-null     object
# dtypes: int64(2), object(8)
# memory usage: 7.9+ KB
# None

# %%
data[:] = np.nan_to_num(data)
data
# Out:
#                                     Name year(below2018) year(above2019)  \
# 0                          Maruti 800 AC             yes              No
# 1               Maruti Wagon R LXI Minor             yes              No
# 2                   Hyundai Verna 1.6 SX             yes              No
# 3                 Datsun RediGO T Option             yes              No
# 4                  Honda Amaze VX i-DTEC             yes              No
# ..                                   ...             ...             ...
# 94          Audi A6 2.0 TDI Premium Plus             yes              No
# 95       Fiat Avventura MULTIJET Emotion             yes              No
# 96                       Audi A8 4.2 TDI             yes              No
# 97                   Datsun RediGO 1.0 S             yes              No
# 98  Volkswagen Jetta 1.4 TSI Comfortline             yes              No
#
#     selling_price  Km_driven  fuel_type  seller_type  transmission  \
# ...

# %%
print(data.describe())
# Out:
#        selling_price      Km_driven
# count   9.900000e+01      99.000000
# mean    6.610303e+05   66306.282828
# std     9.047269e+05   50480.189522
# min     6.000000e+04    4500.000000
# 25%     2.500000e+05   32000.000000
# 50%     4.500000e+05   60000.000000
# 75%     7.500000e+05   80000.000000
# max     8.150000e+06  350000.000000

# %%
# checking the number of missing values
data.isnull().sum()
# Out:
#            Name    0
# year(below2018)    0
# year(above2019)    0
# selling_price      0
# Km_driven          0
# fuel_type          0
# seller_type        0
# transmission       0
# single_owner       0
# multiple_owner     0
# dtype: int64

# %%
data[:] = np.nan_to_num(data)
data
# Out:
#                                     Name year(below2018) year(above2019)  \
# 0                          Maruti 800 AC             yes              No
# 1               Maruti Wagon R LXI Minor             yes              No
# 2                   Hyundai Verna 1.6 SX             yes              No
# 3                 Datsun RediGO T Option             yes              No
# 4                  Honda Amaze VX i-DTEC             yes              No
# ..                                   ...             ...             ...
# 94          Audi A6 2.0 TDI Premium Plus             yes              No
# 95       Fiat Avventura MULTIJET Emotion             yes              No
# 96                       Audi A8 4.2 TDI             yes              No
# 97                   Datsun RediGO 1.0 S             yes              No
# 98  Volkswagen Jetta 1.4 TSI Comfortline             yes              No
#
#     selling_price  Km_driven  fuel_type  seller_type  transmission  \
# ...

# %%
# Converting the categorical variable into numerical
varlist =  ['year(below2018)']
def binary_map(x):
    return x.map({'yes': 1, "no": 0})
    data[varlist] = usedcar[varlist].apply(binary_map)
varlist =  ['year(above2019)']
def binary_map(x):
    return x.map({'yes': 1, "no": 0})
    data[varlist] = usedcar[varlist].apply(binary_map)
varlist =  ['single_owner']
def binary_map(x):
    return x.map({'yes': 1, "no": 0})
    data[varlist] = usedcar[varlist].apply(binary_map)
varlist =  ['multiple_owner']
def binary_map(x):
    return x.map({'yes': 1, "no": 0})
    data[varlist] = usedcar[varlist].apply(binary_map)

# %%
data.head()
# Out:
#                        Name year(below2018) year(above2019)  selling_price  \
# 0             Maruti 800 AC             yes              No          60000
# 1  Maruti Wagon R LXI Minor             yes              No         135000
# 2      Hyundai Verna 1.6 SX             yes              No         600000
# 3    Datsun RediGO T Option             yes              No         250000
# 4     Honda Amaze VX i-DTEC             yes              No         450000
#
#    Km_driven  fuel_type  seller_type  transmission single_owner multiple_owner
# 0      70000          0            1             0          yes             No
# 1      50000          0            1             0          yes             No
# 2     100000          1            1             0          yes             No
# 3      46000          0            1             0          yes             No
# 4     141000          1            1             0           No            yes

# %%
# checking the distribution of categorial data
print(data.fuel_type.value_counts())
print(data.seller_type.value_counts())
print(data.transmission.value_counts())
# Out:
# Petrol    51
# Diesel    48
# Name: fuel_type, dtype: int64
# Individual    64
# Dealer        35
# Name: seller_type, dtype: int64
# Manual       82
# Automatic    17
# Name: transmission, dtype: int64

# %%
# encoding "fuel_type" Column
data.replace({'fuel_type':{'Petrol':0,'Diesel':1}},inplace=True)

# encoding "seller_type" Column
data.replace({'seller_type':{'Dealer':0,'Individual':1}},inplace=True)

# encoding "transmission" Column
data.replace({'transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
data.head()
# Out:
#                        Name year(below2018) year(above2019)  selling_price  \
# 0             Maruti 800 AC             yes              No          60000
# 1  Maruti Wagon R LXI Minor             yes              No         135000
# 2      Hyundai Verna 1.6 SX             yes              No         600000
# 3    Datsun RediGO T Option             yes              No         250000
# 4     Honda Amaze VX i-DTEC             yes              No         450000
#
#    Km_driven  fuel_type  seller_type  transmission single_owner multiple_owner
# 0      70000          0            1             0          yes             No
# 1      50000          0            1             0          yes             No
# 2     100000          1            1             0          yes             No
# 3      46000          0            1             0          yes             No
# 4     141000          1            1             0           No            yes

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(data, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# Applying scaler() to all the columns except the 'yes-no' and 'dummy' variables
num_vars = ['selling_price']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])
df_test[num_vars] = scaler.fit_transform(df_test[num_vars])

df_train
# Out:
#                                                  Name year(below2018)  \
# 25                    Toyota Corolla Altis 1.8 VL CVT             yes
# 40                   Jeep Compass 1.4 Sport Plus BSIV              No
# 54                    Maruti Swift Dzire VDI Optional             yes
# 89  Mercedes-Benz S-Class S 350d Connoisseurs Edition             yes
# 84                      Hyundai Grand i10 CRDi Sportz             yes
# ..                                                ...             ...
# 79                               Honda Civic 1.8 V AT             yes
# 87                                    Honda Brio S MT             yes
# 67                                    Maruti Alto LXi             yes
# 24                           Tata Indigo Grand Petrol             yes
# 8                            Hyundai Creta 1.6 VTVT S             yes
#
#    year(above2019)  selling_price  Km_driven  fuel_type  seller_type  \
# ...

# %%
# Dividing the training data set into X and Y
y_train = df_train.pop('selling_price')
X_train = df_train
y_test = df_test.pop('selling_price')
X_test = df_test

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-866f485a8758> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_train,y_train)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
# ...
